# %% [markdown]
# # Image Filter : Gaussian Filter

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import lena
from scipy.ndimage.filters import convolve
import scipy.ndimage as nd

# %%
single_dot = np.zeros((101, 101))
single_dot[50, 50] = 1.0
gauss_kernel = nd.gaussian_filter(single_dot, 10)
plt.imshow(gauss_kernel)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0760B238>

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig) # create a 3D model
x, y = np.mgrid[0:101, 0:101]
ax.plot_surface(x,y,gauss_kernel)
fig.add_axes(ax)

# %%
plt.plot(abs(np.fft.rfft(gauss_kernel[:,50])), 'o-') # real fft

# %% [markdown]
#     Q1: 查詢rfft的定義後，想辦法得到下圖。
#     hint: 1. n=512
#           2. 紅色曲線為rttf的角度
#           3. plt.twinx()將兩個曲線畫在同一張圖上
#           4. plt.plot(..., 'r') 畫曲線為紅色

# %%
result = plt.imread('rfft.png')
plt.imshow(result)
plt.axis('off')
plt.gcf().set_figwidth(10)

# %% [markdown]
#     * low-pass filter
